# %% [markdown]
# # Forecast Machile Learning Model with LSTM (long short-term memory)

# %%
import pandas as pd

file_path = 'NVDA.csv'

df = pd.read_csv(file_path)
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1999-01-22  0.437500  0.488281  0.388021  0.410156   0.376358  271468800
# 1  1999-01-25  0.442708  0.458333  0.410156  0.453125   0.415786   51048000
# 2  1999-01-26  0.458333  0.467448  0.411458  0.417969   0.383527   34320000
# 3  1999-01-27  0.419271  0.429688  0.395833  0.416667   0.382332   24436800
# 4  1999-01-28  0.416667  0.419271  0.412760  0.415365   0.381137   22752000

# %%
# selecionando as colunas

df = df[['Date', 'Close']]
df.head()
# Out:
#          Date     Close
# 0  1999-01-22  0.410156
# 1  1999-01-25  0.453125
# 2  1999-01-26  0.417969
# 3  1999-01-27  0.416667
# 4  1999-01-28  0.415365

# %%
# transformanda os dados de Date para o tipo data

import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

# exemplo
datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
# aplicando a função de conversão de tipo de data a coluna Date

df['Date'] = df['Date'].apply(str_to_datetime)
df['Date'].head()
# Out:
# 0   1999-01-22
# 1   1999-01-25
# 2   1999-01-26
# 3   1999-01-27
# 4   1999-01-28
# Name: Date, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df.head()
# Out:
#                Close
# Date
# 1999-01-22  0.410156
# 1999-01-25  0.453125
# 1999-01-26  0.417969
# 1999-01-27  0.416667
# 1999-01-28  0.415365

# %%
# visualizando os dados

import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
# transforma o dataframe em um dataframe com "janela"

import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date = str_to_datetime(last_date_str)

  target_date = first_date

  dates, X, Y = [], [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                # '1999-03-25',
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df.head()
# Out:
#   Target Date    Target-3    Target-2    Target-1      Target
# 0  2021-03-25  131.862503  130.707504  126.430000  125.352501
# 1  2021-03-26  130.707504  126.430000  125.352501  128.392502
# 2  2021-03-29  126.430000  125.352501  128.392502  129.482498
# 3  2021-03-30  125.352501  128.392502  129.482498  128.717499
# 4  2021-03-31  128.392502  129.482498  128.717499  133.482498

# %%
# transforma o dado para ser utilizado pelo modelo de machine learning

def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy() # converte para numpy array

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape(len(dates), middle_matrix.shape[1], 1)

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)
dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
# dadps de treino, validação e teste 

q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
# criando e treinando o modelo

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# definindo o modelo
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 98ms/step - loss: 48942.9062 - mean_absolute_error: 214.0840 - val_loss: 61850.5664 - val_mean_absolute_error: 248.1438
# Epoch 2/100
# 7/7 [==============================] - 0s 9ms/step - loss: 48723.9453 - mean_absolute_error: 213.5664 - val_loss: 61637.5547 - val_mean_absolute_error: 247.7143
# Epoch 3/100
# 7/7 [==============================] - 0s 9ms/step - loss: 48520.3672 - mean_absolute_error: 213.0928 - val_loss: 61338.6094 - val_mean_absolute_error: 247.1103
# Epoch 4/100
# 7/7 [==============================] - 0s 9ms/step - loss: 48246.4336 - mean_absolute_error: 212.4506 - val_loss: 61003.5898 - val_mean_absolute_error: 246.4312
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47931.1953 - mean_absolute_error: 211.6966 - val_loss: 60585.5938 - val_mean_absolute_error: 245.5809
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: 47475.5586 - mean_absolute_error: 210.6157 - val_loss: 59881.2539 - val_mean_absolute_error: 244.1426
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 46820.3984 - mean_absolute_error: 209.0477 - val_loss: 59042.5117 - val_mean_absolute_error: 242.4184
# Epoch 8/100
# 7/7 [==============================] - 0s 10ms/step - loss: 45977.1484 - mean_absolute_error: 207.0024 - val_loss: 57778.8047 - val_mean_absolute_error: 239.7978
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 44729.6523 - mean_absolute_error: 203.9618 - val_loss: 56009.6133 - val_mean_absolute_error: 236.0773
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 42946.9492 - mean_absolute_error: 199.4695 - val_loss: 53448.3438 - val_mean_absolute_error: 230.5885
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 40602.2070 - mean_absolute_error: 193.5405 - val_loss: 50462.3711 - val_mean_absolute_error: 224.0222
# Epoch 12/100
# 7/7 [==============================] - 0s 12ms/step - loss: 37988.6758 - mean_absolute_error: 186.6679 - val_loss: 47122.8516 - val_mean_absolute_error: 216.4404
# Epoch 13/100
# 7/7 [==============================] - 0s 15ms/step - loss: 35011.2695 - mean_absolute_error: 178.4397 - val_loss: 43203.3086 - val_mean_absolute_error: 207.1782
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 31296.5801 - mean_absolute_error: 167.6130 - val_loss: 38103.3867 - val_mean_absolute_error: 194.4905
# Epoch 15/100
# 7/7 [==============================] - 0s 14ms/step - loss: 27278.3887 - mean_absolute_error: 155.3588 - val_loss: 33498.3984 - val_mean_absolute_error: 182.2685
# Epoch 16/100
# 7/7 [==============================] - 0s 16ms/step - loss: 23406.7539 - mean_absolute_error: 142.1387 - val_loss: 28401.2656 - val_mean_absolute_error: 167.6959
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 18954.8184 - mean_absolute_error: 124.9329 - val_loss: 21808.5391 - val_mean_absolute_error: 146.7094
# Epoch 18/100
# 7/7 [==============================] - 0s 15ms/step - loss: 13852.1055 - mean_absolute_error: 103.0936 - val_loss: 15729.4023 - val_mean_absolute_error: 124.3014
# Epoch 19/100
# 7/7 [==============================] - 0s 12ms/step - loss: 9829.7217 - mean_absolute_error: 82.4023 - val_loss: 11190.2305 - val_mean_absolute_error: 104.4603
# Epoch 20/100
# 7/7 [==============================] - 0s 13ms/step - loss: 7003.8550 - mean_absolute_error: 65.2285 - val_loss: 7117.2207 - val_mean_absolute_error: 82.7118
# Epoch 21/100
# 7/7 [==============================] - 0s 12ms/step - loss: 4874.3657 - mean_absolute_error: 53.9731 - val_loss: 4488.0518 - val_mean_absolute_error: 64.9070
# Epoch 22/100
# 7/7 [==============================] - 0s 15ms/step - loss: 3703.9578 - mean_absolute_error: 46.1141 - val_loss: 2843.9351 - val_mean_absolute_error: 50.6831
# Epoch 23/100
# 7/7 [==============================] - 0s 13ms/step - loss: 3239.9634 - mean_absolute_error: 43.7737 - val_loss: 1908.1334 - val_mean_absolute_error: 40.4101
# Epoch 24/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3126.8037 - mean_absolute_error: 44.3879 - val_loss: 1409.7080 - val_mean_absolute_error: 33.6831
# Epoch 25/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3110.4543 - mean_absolute_error: 45.1567 - val_loss: 1242.2772 - val_mean_absolute_error: 31.0988
# Epoch 26/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3116.6189 - mean_absolute_error: 45.4486 - val_loss: 1238.6332 - val_mean_absolute_error: 31.0554
# Epoch 27/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3041.6606 - mean_absolute_error: 44.6671 - val_loss: 1373.4742 - val_mean_absolute_error: 33.2729
# Epoch 28/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3000.5842 - mean_absolute_error: 44.2761 - val_loss: 1277.0400 - val_mean_absolute_error: 31.7754
# Epoch 29/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2916.9485 - mean_absolute_error: 43.4046 - val_loss: 1586.2621 - val_mean_absolute_error: 36.6339
# Epoch 30/100
# 7/7 [==============================] - 0s 17ms/step - loss: 2601.4265 - mean_absolute_error: 39.7826 - val_loss: 1364.4738 - val_mean_absolute_error: 33.6353
# Epoch 31/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2375.0369 - mean_absolute_error: 37.8876 - val_loss: 1451.5568 - val_mean_absolute_error: 35.2991
# Epoch 32/100
# 7/7 [==============================] - 0s 15ms/step - loss: 2142.1841 - mean_absolute_error: 34.8200 - val_loss: 1256.6519 - val_mean_absolute_error: 32.4133
# Epoch 33/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1796.8569 - mean_absolute_error: 30.7954 - val_loss: 974.5837 - val_mean_absolute_error: 28.1335
# Epoch 34/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1521.1471 - mean_absolute_error: 28.7890 - val_loss: 919.6227 - val_mean_absolute_error: 27.7688
# Epoch 35/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1238.9769 - mean_absolute_error: 25.0151 - val_loss: 477.4922 - val_mean_absolute_error: 18.3628
# Epoch 36/100
# 7/7 [==============================] - 0s 13ms/step - loss: 984.0124 - mean_absolute_error: 22.1076 - val_loss: 355.2090 - val_mean_absolute_error: 15.6226
# Epoch 37/100
# 7/7 [==============================] - 0s 15ms/step - loss: 732.3188 - mean_absolute_error: 17.8917 - val_loss: 212.9419 - val_mean_absolute_error: 11.7123
# Epoch 38/100
# 7/7 [==============================] - 0s 12ms/step - loss: 520.2733 - mean_absolute_error: 13.7900 - val_loss: 113.9080 - val_mean_absolute_error: 8.7813
# Epoch 39/100
# 7/7 [==============================] - 0s 12ms/step - loss: 372.7306 - mean_absolute_error: 11.9953 - val_loss: 95.4571 - val_mean_absolute_error: 8.1149
# Epoch 40/100
# 7/7 [==============================] - 0s 15ms/step - loss: 264.5500 - mean_absolute_error: 9.8276 - val_loss: 118.5569 - val_mean_absolute_error: 8.9860
# Epoch 41/100
# 7/7 [==============================] - 0s 16ms/step - loss: 196.3345 - mean_absolute_error: 8.8377 - val_loss: 102.8567 - val_mean_absolute_error: 8.2517
# Epoch 42/100
# 7/7 [==============================] - 0s 16ms/step - loss: 149.7357 - mean_absolute_error: 7.7775 - val_loss: 102.1305 - val_mean_absolute_error: 8.1403
# Epoch 43/100
# 7/7 [==============================] - 0s 14ms/step - loss: 119.1310 - mean_absolute_error: 7.3636 - val_loss: 114.0592 - val_mean_absolute_error: 8.5443
# Epoch 44/100
# 7/7 [==============================] - 0s 12ms/step - loss: 92.5258 - mean_absolute_error: 6.5034 - val_loss: 216.0231 - val_mean_absolute_error: 12.3526
# Epoch 45/100
# 7/7 [==============================] - 0s 13ms/step - loss: 76.6152 - mean_absolute_error: 6.0891 - val_loss: 197.5087 - val_mean_absolute_error: 11.6853
# Epoch 46/100
# 7/7 [==============================] - 0s 13ms/step - loss: 66.8925 - mean_absolute_error: 5.7153 - val_loss: 197.3192 - val_mean_absolute_error: 11.6655
# Epoch 47/100
# 7/7 [==============================] - 0s 13ms/step - loss: 60.5133 - mean_absolute_error: 5.4301 - val_loss: 204.4185 - val_mean_absolute_error: 11.9264
# Epoch 48/100
# 7/7 [==============================] - 0s 17ms/step - loss: 56.6647 - mean_absolute_error: 5.3369 - val_loss: 124.1872 - val_mean_absolute_error: 8.9552
# Epoch 49/100
# 7/7 [==============================] - 0s 14ms/step - loss: 56.9105 - mean_absolute_error: 5.3388 - val_loss: 153.4767 - val_mean_absolute_error: 9.9204
# Epoch 50/100
# 7/7 [==============================] - 0s 15ms/step - loss: 53.4156 - mean_absolute_error: 5.0378 - val_loss: 285.7587 - val_mean_absolute_error: 14.6037
# Epoch 51/100
# 7/7 [==============================] - 0s 14ms/step - loss: 55.5819 - mean_absolute_error: 5.2708 - val_loss: 188.9177 - val_mean_absolute_error: 11.2747
# Epoch 52/100
# 7/7 [==============================] - 0s 16ms/step - loss: 53.8060 - mean_absolute_error: 5.1028 - val_loss: 183.8897 - val_mean_absolute_error: 11.1016
# Epoch 53/100
# 7/7 [==============================] - 0s 13ms/step - loss: 49.3718 - mean_absolute_error: 4.9101 - val_loss: 184.3615 - val_mean_absolute_error: 11.0879
# Epoch 54/100
# 7/7 [==============================] - 0s 16ms/step - loss: 51.1451 - mean_absolute_error: 5.1830 - val_loss: 159.9469 - val_mean_absolute_error: 10.1764
# Epoch 55/100
# 7/7 [==============================] - 0s 13ms/step - loss: 53.5571 - mean_absolute_error: 5.2357 - val_loss: 155.6821 - val_mean_absolute_error: 10.0267
# Epoch 56/100
# 7/7 [==============================] - 0s 14ms/step - loss: 48.3982 - mean_absolute_error: 4.9150 - val_loss: 131.0722 - val_mean_absolute_error: 9.2198
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 50.1850 - mean_absolute_error: 5.0495 - val_loss: 116.4845 - val_mean_absolute_error: 8.6928
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 49.6985 - mean_absolute_error: 4.9223 - val_loss: 118.3386 - val_mean_absolute_error: 8.7365
# Epoch 59/100
# 7/7 [==============================] - 0s 8ms/step - loss: 51.1167 - mean_absolute_error: 4.8454 - val_loss: 254.4076 - val_mean_absolute_error: 13.6534
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 61.2728 - mean_absolute_error: 5.7721 - val_loss: 311.7877 - val_mean_absolute_error: 15.3646
# Epoch 61/100
# 7/7 [==============================] - 0s 9ms/step - loss: 57.6548 - mean_absolute_error: 5.6821 - val_loss: 137.9084 - val_mean_absolute_error: 9.5254
# Epoch 62/100
# 7/7 [==============================] - 0s 13ms/step - loss: 49.1920 - mean_absolute_error: 4.9323 - val_loss: 111.1425 - val_mean_absolute_error: 8.4730
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.0062 - mean_absolute_error: 4.8258 - val_loss: 163.5378 - val_mean_absolute_error: 10.3117
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.6841 - mean_absolute_error: 4.8786 - val_loss: 158.4192 - val_mean_absolute_error: 10.1339
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 46.7999 - mean_absolute_error: 4.7446 - val_loss: 212.6296 - val_mean_absolute_error: 12.2316
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 54.6995 - mean_absolute_error: 5.3931 - val_loss: 147.4579 - val_mean_absolute_error: 9.8895
# Epoch 67/100
# 7/7 [==============================] - 0s 10ms/step - loss: 46.9408 - mean_absolute_error: 4.7933 - val_loss: 111.5391 - val_mean_absolute_error: 8.4752
# Epoch 68/100
# 7/7 [==============================] - 0s 12ms/step - loss: 51.6031 - mean_absolute_error: 4.9772 - val_loss: 131.1788 - val_mean_absolute_error: 9.2067
# Epoch 69/100
# 7/7 [==============================] - 0s 9ms/step - loss: 48.2430 - mean_absolute_error: 4.7200 - val_loss: 120.9400 - val_mean_absolute_error: 8.7844
# Epoch 70/100
# 7/7 [==============================] - 0s 9ms/step - loss: 45.5871 - mean_absolute_error: 4.6259 - val_loss: 139.5835 - val_mean_absolute_error: 9.4312
# Epoch 71/100
# 7/7 [==============================] - 0s 9ms/step - loss: 46.5184 - mean_absolute_error: 4.7600 - val_loss: 106.7512 - val_mean_absolute_error: 8.2659
# Epoch 72/100
# 7/7 [==============================] - 0s 9ms/step - loss: 49.2022 - mean_absolute_error: 4.9657 - val_loss: 111.6920 - val_mean_absolute_error: 8.4653
# Epoch 73/100
# 7/7 [==============================] - 0s 10ms/step - loss: 42.8614 - mean_absolute_error: 4.6543 - val_loss: 214.7021 - val_mean_absolute_error: 12.2269
# Epoch 74/100
# 7/7 [==============================] - 0s 12ms/step - loss: 48.1405 - mean_absolute_error: 5.1550 - val_loss: 142.7706 - val_mean_absolute_error: 9.5879
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.2148 - mean_absolute_error: 5.0607 - val_loss: 104.8528 - val_mean_absolute_error: 8.4679
# Epoch 76/100
# 7/7 [==============================] - 0s 14ms/step - loss: 64.4721 - mean_absolute_error: 6.0371 - val_loss: 126.6990 - val_mean_absolute_error: 9.0636
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 55.4419 - mean_absolute_error: 5.3275 - val_loss: 240.7908 - val_mean_absolute_error: 13.2247
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 50.7473 - mean_absolute_error: 5.1281 - val_loss: 145.0798 - val_mean_absolute_error: 9.6101
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 46.2652 - mean_absolute_error: 4.7598 - val_loss: 112.4720 - val_mean_absolute_error: 8.4392
# Epoch 80/100
# 7/7 [==============================] - 0s 10ms/step - loss: 48.6469 - mean_absolute_error: 4.7686 - val_loss: 109.7538 - val_mean_absolute_error: 8.3939
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.8628 - mean_absolute_error: 4.7129 - val_loss: 136.1020 - val_mean_absolute_error: 9.3001
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 46.3318 - mean_absolute_error: 4.7873 - val_loss: 165.9271 - val_mean_absolute_error: 10.3189
# Epoch 83/100
# 7/7 [==============================] - 0s 12ms/step - loss: 53.8538 - mean_absolute_error: 5.3965 - val_loss: 100.9832 - val_mean_absolute_error: 8.0341
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 61.7936 - mean_absolute_error: 6.0155 - val_loss: 126.6439 - val_mean_absolute_error: 9.1263
# Epoch 85/100
# 7/7 [==============================] - 0s 13ms/step - loss: 70.6252 - mean_absolute_error: 6.4713 - val_loss: 220.5001 - val_mean_absolute_error: 12.5023
# Epoch 86/100
# 7/7 [==============================] - 0s 9ms/step - loss: 50.8846 - mean_absolute_error: 5.2652 - val_loss: 215.4695 - val_mean_absolute_error: 12.4189
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 51.8383 - mean_absolute_error: 5.2387 - val_loss: 93.5492 - val_mean_absolute_error: 7.7489
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.2615 - mean_absolute_error: 4.9378 - val_loss: 149.7791 - val_mean_absolute_error: 9.7934
# Epoch 89/100
# 7/7 [==============================] - 0s 9ms/step - loss: 45.3848 - mean_absolute_error: 4.6494 - val_loss: 182.3818 - val_mean_absolute_error: 11.0503
# Epoch 90/100
# 7/7 [==============================] - 0s 10ms/step - loss: 45.7645 - mean_absolute_error: 4.7314 - val_loss: 130.7114 - val_mean_absolute_error: 9.1487
# Epoch 91/100
# 7/7 [==============================] - 0s 9ms/step - loss: 44.9305 - mean_absolute_error: 4.6853 - val_loss: 115.7031 - val_mean_absolute_error: 8.5805
# Epoch 92/100
# 7/7 [==============================] - 0s 9ms/step - loss: 49.5515 - mean_absolute_error: 4.9179 - val_loss: 152.3334 - val_mean_absolute_error: 9.8403
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 50.2273 - mean_absolute_error: 4.7831 - val_loss: 235.4703 - val_mean_absolute_error: 13.1026
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 50.3643 - mean_absolute_error: 5.2402 - val_loss: 105.5618 - val_mean_absolute_error: 8.2164
# Epoch 95/100
# 7/7 [==============================] - 0s 9ms/step - loss: 52.3233 - mean_absolute_error: 5.3900 - val_loss: 134.7760 - val_mean_absolute_error: 9.2029
# Epoch 96/100
# 7/7 [==============================] - 0s 12ms/step - loss: 48.9144 - mean_absolute_error: 4.7340 - val_loss: 193.2772 - val_mean_absolute_error: 11.5564
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 48.8393 - mean_absolute_error: 4.8218 - val_loss: 200.6492 - val_mean_absolute_error: 11.8357
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 47.9523 - mean_absolute_error: 5.1655 - val_loss: 105.2581 - val_mean_absolute_error: 8.1986
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 44.4568 - mean_absolute_error: 4.5690 - val_loss: 139.9832 - val_mean_absolute_error: 9.3965
# Epoch 100/100
# 7/7 [==============================] - 0s 9ms/step - loss: 52.0010 - mean_absolute_error: 5.1610 - val_loss: 144.2261 - val_mean_absolute_error: 9.6347

# %%
# visualização dos dados treinados

train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 4ms/step

# %%
# visualizando os dados treinados

val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
# visualizando os dados de teste

test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
# visualização geral

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val , y_val)
plt.plot(dates_test , test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predicitons',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
# predição recursiva

from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
# visualização geral

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val , y_val)
plt.plot(dates_test , test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predicitons',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
